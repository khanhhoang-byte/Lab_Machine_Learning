# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.array([
    [1, 2],
    [2, 3],])
x, y = data.T
plt.scatter(x,y)
plt.show()

# %%
arr = np.array([[1,2],[2,1]])
x,y = np.add(data, arr)
plt.scatter(x,y)
plt.show()
