# %%
import pandas as pd

# %%
adult_df = pd.read_csv('adult.csv')

# %%
adult_df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
adult_df['income >50K'] = adult_df['income'].apply(lambda income: 1 if income == ">50K" else 0)

# %%
adult_df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
adult_df = adult_df.drop('income', axis=1)

# %%
adult_df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
adult_train_val, adult_test = train_test_split(adult_df, test_size=0.1, stratify=adult_df['income >50K'])

# %%
adult_train, adult_val = train_test_split(adult_train_val, test_size = 0.1,stratify=adult_train_val['income >50K'])

# %%
adult_train.shape
# Out:
# (26373, 15)

# %%
adult_test.shape
# Out:
# (3257, 15)

# %%
adult_val.shape
# Out:
# (2931, 15)

# %%
DUMMY_SEP = '__'

# %%
adult_train_dummies = pd.get_dummies(adult_train, prefix_sep=DUMMY_SEP)

# %%
adult_train_dummies
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 26090   39  357962             12             0             0              48
# 21340   30  149507              9             0             0              42
# 26998   21  149809              9             0             0              24
# 11743   43  116632             10             0             0              45
# 30100   43  254817             10             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 11967   40  190290             13             0             0              40
# 2523    51  139347              9          7688             0              40
# 17988   20  151105             12             0             0              25
# 23977   31  281540             12             0             0              45
# 8301    26  138152              8             0             0              48
#
# ...

# %%
train_dummy_columns = [c for c in adult_train_dummies.columns if DUMMY_SEP in c]

# %%
dummy_columns_to_remove = [c for c in train_dummy_columns if adult_train_dummies[c].sum() < 10]

# %%
dummy_columns_to_remove
# Out:
# ['workclass__Never-worked',
#  'workclass__Without-pay',
#  'occupation__Armed-Forces',
#  'native.country__Holand-Netherlands',
#  'native.country__Honduras',
#  'native.country__Scotland']

# %%
adult_train_dummies = adult_train_dummies.drop(dummy_columns_to_remove, axis=1)

# %%
adult_train_dummies
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 26090   39  357962             12             0             0              48
# 21340   30  149507              9             0             0              42
# 26998   21  149809              9             0             0              24
# 11743   43  116632             10             0             0              45
# 30100   43  254817             10             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 11967   40  190290             13             0             0              40
# 2523    51  139347              9          7688             0              40
# 17988   20  151105             12             0             0              25
# 23977   31  281540             12             0             0              45
# 8301    26  138152              8             0             0              48
#
# ...

# %%
def get_dummies_for_test(train_columns, test_df, dummy_sep):
    initial_df = pd.get_dummies(test_df, prefix_sep=dummy_sep)
#     missing_in_train = set(test_df.columns) - set(train_columns)
    missing_in_test = set(train_columns) - set(initial_df.columns)
    
    for c in missing_in_test:
        initial_df[c] = 0
    return initial_df.loc[:,train_columns].copy()

# %%
adult_test_dummies = get_dummies_for_test(adult_train_dummies.columns, adult_test, DUMMY_SEP)
adult_val_dummies = get_dummies_for_test(adult_train_dummies.columns, adult_val, DUMMY_SEP)

# %%
adult_val_dummies
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 10775   64  256466              9             0             0              60
# 22146   47  217161              9             0             0              14
# 14922   36   81896             13             0             0              45
# 1389    46  175109              9             0          1485              40
# 4799    35  292472             16             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 23587   19   43887              9             0             0              10
# 29006   51  467611              5             0             0              40
# 21457   29   46609              6             0             0              40
# 11645   79  333230              9             0             0               6
# 13511   33  223046              9             0             0              40
#
# ...

# %%
X_train, y_train = adult_train_dummies.drop("income >50K",axis=1), adult_train_dummies['income >50K']
X_test, y_test = adult_test_dummies.drop("income >50K",axis=1), adult_test_dummies['income >50K']
X_val, y_val = adult_val_dummies.drop("income >50K",axis=1), adult_val_dummies['income >50K']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve

# %%
dtree_clf = DecisionTreeClassifier(min_samples_split=20)

# %%
dtree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=20)

# %%
accuracy_score(y_val, dtree_clf.predict(X_val))
# Out:
# 0.8355510064824292

# %%
print(classification_report(y_train, dtree_clf.predict(X_train)))
print(classification_report(y_val, dtree_clf.predict(X_val)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95     20022
#            1       0.87      0.78      0.82      6351
#
#     accuracy                           0.92     26373
#    macro avg       0.90      0.87      0.89     26373
# weighted avg       0.92      0.92      0.92     26373
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89      2225
#            1       0.68      0.60      0.64       706
#
#     accuracy                           0.84      2931
#    macro avg       0.78      0.76      0.77      2931
# weighted avg       0.83      0.84      0.83      2931

# %%
probs = dtree_clf.predict_proba(X_val)[:,1]

# %%
fpr, tpr, thresholds = roc_curve(y_val, probs)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot([0,1],[0,1])
plt.show()

# %%
roc_auc_score(y_val, probs)
# Out:
# 0.831926027310055
